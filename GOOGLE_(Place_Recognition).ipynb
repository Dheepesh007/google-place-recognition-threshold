# %%
# SESSION 12 – GOOGLE (Place Recognition)

# Define similarity score and threshold
similarity = 0.94
threshold = 0.9

# Check place recognition
if similarity > threshold:
    recognized = True
    print("Place Recognized")
else:
    recognized = False
    print("Place Not Recognized")
